# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Fetch Sleeper ADP data
response = requests.get("https://api.sleeper.app/v1/players/nfl")
players = response.json()

# Example: Converting to DataFrame
player_data = pd.DataFrame(players).T  # Transpose to handle JSON structure

# %%
player_data
# Out:
#       sport         full_name practice_description         high_school  \
# 6462    nfl  Ellis Richardson                 None      Douglas County
# 11255   nfl        Nick Amoah                 None          Davis (CA)
# 8842    nfl  Malkelm Morrison                 None      Iona Prep (NY)
# 7926    nfl       Carl Tucker                 None          Hough (NC)
# 1875    nfl       C.J. Mosley                 None       Theodore (AL)
# ...     ...               ...                  ...                 ...
# 4810    nfl     Kwayde Miller                 None              Ramona
# 918     nfl        Niles Paul                 None  Millard North (NE)
# 1591    nfl      Alvin Bailey                 None   Broken Arrow (OK)
# 6744    nfl         Greg Ward                 None     John Tyler (TX)
# 3992    nfl     Dave Caldwell                 None                None
#
#                           hashtag active player_id search_last_name  espn_id  \
# ...

# %%
import nfl_data_py as nfl
import pandas as pd

# Step 1: Import rosters for the range of seasons
seasons = list(range(2018, 2024))  # Create a list for seasons 2018 to 2023
rosters = nfl.import_seasonal_rosters(seasons)

# Step 2: Remove duplicates by 'player_id'
unique_rosters = rosters.drop_duplicates(subset='player_id')

# Step 3: Drop the 'season' column
cleaned_rosters = unique_rosters.drop(columns=['season'])

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

# %%
cleaned_rosters.head(20)
# Out:
#    team position depth_chart_position  jersey_number status  \
# 0   ARI        K                    K            4.0    RES
# 1   IND        K                    K            4.0    ACT
# 2    NE       QB                   QB           12.0    ACT
# 3   SEA        K                    K           11.0    ACT
# 4   HOU        P                    P            9.0    CUT
# 5    NO       QB                   QB            9.0    ACT
# 6   ATL        K                    K            3.0    ACT
# 7   CAR       DL                   DE           90.0    ACT
# 8   NYJ       QB                   QB           15.0    ACT
# 9   LAC       TE                   TE           85.0    ACT
# 10  MIN       DB                   CB           23.0    CUT
# 11  BAL       LB                  OLB           55.0    ACT
# 12  CAR       DB                   FS           29.0    ACT
# 13  DET       LS                   LS           48.0    ACT
# 14  PHI       OL                   OT           71.0    ACT
# ...

# %%
pstat_2023_df = pd.read_csv('seasonalstats/player_stats_2023.csv')

# %%
pd.merge(left = pstat_2023_df[['player_id', 'player_name']], right = cleaned_rosters[['player_id','player_name', 'first_name', 'last_name', 'espn_id']], on='player_id')
# Out:
#       player_id player_name_x       player_name_y first_name   last_name  \
# 0    00-0023459     A.Rodgers       Aaron Rodgers      Aaron     Rodgers
# 1    00-0023853      M.Prater         Matt Prater       Matt      Prater
# 2    00-0024243       M.Lewis      Marcedes Lewis   Marcedes       Lewis
# 3    00-0025565        N.Folk           Nick Folk       Nick        Folk
# 4    00-0025580      M.Crosby        Mason Crosby      Mason      Crosby
# ..          ...           ...                 ...        ...         ...
# 628  00-0039150       B.Young         Bryce Young      Bryce       Young
# 629  00-0039152       W.Levis          Will Levis       Will       Levis
# 630  00-0039163      C.Stroud         C.J. Stroud  Coleridge      Stroud
# 631  00-0039164  A.Richardson  Anthony Richardson    Anthony  Richardson
# 632  00-0039165  Z.Charbonnet     Zach Charbonnet       Zach  Charbonnet
#
#     espn_id
# 0      8439
# 1     11122
# 2      9614
# 3     10621
# 4     10636
# ...
