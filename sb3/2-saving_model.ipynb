# %%
#pip install tensorboard

# %%
import gymnasium as gym
from stable_baselines3 import PPO, A2C

import os

models = "PPO"
models_dir = f"notebook/sb3/models/{models}"
logdir = "notebook/sb3/logs"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

# Create the environment
env = gym.make("LunarLander-v3")
obs, info = env.reset()  # Unpack the reset output (obs, info)

model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=logdir)

TIMESTEPS = 100000

for i in range(1, 30):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=models)
    model.save(f"{models_dir}/{TIMESTEPS}*i")

# episodes = 10

# for ep in range(episodes):
#     obs = env.reset()
#     done = False

#     while not done:

#         env.render()
#         action = env.action_space.sample()  # Sample a random action
#         obs, reward, done, truncated, info = env.step(action)  # Update to include 'truncated'
#         # print(reward)
#         if done or truncated:  # Check for termination or truncation
#             obs, info = env.reset()  # Reset the environment

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to notebook/sb3/logs/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.3     |
# |    ep_rew_mean     | -132     |
# | time/              |          |
# |    fps             | 6009     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.6        |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 4061        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011558084 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00241     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 393         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00897    |
# |    value_loss           | 1.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.6        |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 3541        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008684239 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 392         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00812    |
# |    value_loss           | 864         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94          |
# |    ep_rew_mean          | -149        |
# | time/                   |             |
# |    fps                  | 3455        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012010167 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0246     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 243         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 658         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.6         |
# |    ep_rew_mean          | -146         |
# | time/                   |              |
# |    fps                  | 3375         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0076602167 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0111      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 256          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0066      |
# |    value_loss           | 845          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 104        |
# |    ep_rew_mean          | -149       |
# | time/                   |            |
# |    fps                  | 3330       |
# |    iterations           | 6          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01207789 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | -0.00051   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 199        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00967   |
# |    value_loss           | 361        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | -149         |
# | time/                   |              |
# |    fps                  | 3308         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0077508204 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.0476      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 473          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0071      |
# |    value_loss           | 664          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 3280         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0099084135 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.000133    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 209          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0067      |
# |    value_loss           | 363          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 124        |
# |    ep_rew_mean          | -131       |
# | time/                   |            |
# |    fps                  | 3269       |
# |    iterations           | 9          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00978923 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | -0.000773  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 195        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 405        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | -126        |
# | time/                   |             |
# |    fps                  | 3243        |
# |    iterations           | 10          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007746336 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -5.03e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.6        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 207         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 3239        |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009981284 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -0.000152   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00966    |
# |    value_loss           | 403         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 3239        |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007617627 |
# |    clip_fraction        | 0.0263      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | -0.000208   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00517    |
# |    value_loss           | 278         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 3236         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0042293933 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000251    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 281          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 384          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 3235        |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006907592 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -7.83e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 362         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 3229         |
# |    iterations           | 15           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0074950084 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -2.13e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 161          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00481     |
# |    value_loss           | 360          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -104         |
# | time/                   |              |
# |    fps                  | 3229         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0026566763 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 6.48e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 340          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 493          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 207          |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 3230         |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0044474285 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.000192     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 154          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 342          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 221          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 3230         |
# |    iterations           | 18           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0024348102 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.00907      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 317          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | -96.1       |
# | time/                   |             |
# |    fps                  | 3228        |
# |    iterations           | 19          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008795786 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00914    |
# |    value_loss           | 84.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 249          |
# |    ep_rew_mean          | -95.7        |
# | time/                   |              |
# |    fps                  | 3228         |
# |    iterations           | 20           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0036178245 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.304        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63           |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 144          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 265          |
# |    ep_rew_mean          | -91.4        |
# | time/                   |              |
# |    fps                  | 3230         |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0020109718 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 151          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 305          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 273          |
# |    ep_rew_mean          | -89.2        |
# | time/                   |              |
# |    fps                  | 3218         |
# |    iterations           | 22           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0037126718 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.8         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00364     |
# |    value_loss           | 189          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 286          |
# |    ep_rew_mean          | -87.5        |
# | time/                   |              |
# |    fps                  | 3189         |
# |    iterations           | 23           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0065479027 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.481        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 283          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00519     |
# |    value_loss           | 297          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | -84.4       |
# | time/                   |             |
# |    fps                  | 3184        |
# |    iterations           | 24          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006840918 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00586    |
# |    value_loss           | 223         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | -81.6       |
# | time/                   |             |
# |    fps                  | 3182        |
# |    iterations           | 25          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008793875 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.1        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 127         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | -79         |
# | time/                   |             |
# |    fps                  | 3179        |
# |    iterations           | 26          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008072058 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 198         |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      22 TIMESTEPS = 100000
#      24 for i in range(1, 30):
# ---> 25     model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=models)
#      26     model.save(f"{models_dir}/{TIMESTEPS}*i")
#      28 # episodes = 10
#      29
#      30 # for ep in range(episodes):
#    (...)
#      40 #         if done or truncated:  # Check for termination or truncation
#      41 #             obs, info = env.reset()  # Reset the environment
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/stable_baselines3/common/policies.py:645, in ActorCriticPolicy.forward(self, obs, deterministic)
#     637 """
#     638 Forward pass in all the networks (actor and critic)
#     639
#    (...)
#     642 :return: action, value and log probability of the action
#     643 """
#     644 # Preprocess the observation if needed
# --> 645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
#     647     latent_pi, latent_vf = self.mlp_extractor(features)
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/stable_baselines3/common/policies.py:672, in ActorCriticPolicy.extract_features(self, obs, features_extractor)
#     663 """
#     664 Preprocess the observation if needed and extract features.
#     665
#    (...)
#     669     features for the actor and the features for the critic.
#     670 """
#     671 if self.share_features_extractor:
# --> 672     return super().extract_features(obs, self.features_extractor if features_extractor is None else features_extractor)
#     673 else:
#     674     if features_extractor is not None:
#
# File /opt/anaconda3/envs/draftai/lib/python3.9/site-packages/torch/nn/modules/module.py:1918, in Module.__getattr__(self, name)
#    1909         self._backward_pre_hooks = OrderedDict()
#    1911 # On the return type:
#    1912 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1913 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1916 # See full discussion on the problems with returning `Union` here
#    1917 # https://github.com/microsoft/pyright/issues/4213
# -> 1918 def __getattr__(self, name: str) -> Any:
#    1919     if "_parameters" in self.__dict__:
#    1920         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:
